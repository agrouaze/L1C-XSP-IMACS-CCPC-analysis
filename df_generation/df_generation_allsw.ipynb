# %% [markdown]
# # Generation of a one slice dataframe from a l1c product

# %%
import glob
import pandas as pd
import sys 

path_tools = '/home1/datahome/ljessel/'   # path to the python script directory
sys.path.append(path_tools)
from L1B_nc_conversion_L1C_csv.l1c_conversion_approp import L1CConverter

# %% [markdown]
# ## 0) loading the l1c files

# %%
path = '/home/datawork-cersat-public/cache/project/sarwave/data/products/tests/iw/slc/l1c/4.1/'
safe = 'S1B_IW_XSP__1SDV_20210823T181530_20210823T181557_028377_0362CD_CE8B.SAFE'
fns = glob.glob(path+safe+'/*.nc')  # the iw2 sub_swaths have a five 5 tile_sample whereas the 2 others (iw1 et iw3) have a 4 tile_sample

# %% [markdown]
# ## 1) generation of the dataframes from the l1c's

# %%
root_savepath = '/home1/datawork/ljessel/l1c_converted/4.1'
selected_vars = ['sigma0', 'sigma0_filt','incidence','nesz_filt', 'ground_heading', 'azimuth_cutoff',
                 'land_flag', 'uwnd', 'vwnd','U10', 'V10', 'macs_Im', 'macs_Re',
                 'normalized_variance_filt']
for input_path in fns:
    l1c_converter = L1CConverter(input_path, root_savepath, selected_vars, 'intraburst')
    l1c_converter.converter(save=True)

# %% [markdown]
# ## 2) loading the dataframes & merging into one single dataframe

# %%
safe_path = '/home1/datawork/ljessel/l1c_converted/4.1/S1B_IW_XSP__1SDV_20210823T181530_20210823T181557_028377_0362CD_CE8B.SAFE/intraburst/'
csv_vv = glob.glob(safe_path+'/*vv*.csv') 
#csv_vh = glob.glob(safe_path+'/*vh*.csv')

df_tot = pd.read_csv(csv_vv[0])
#(df_tot = pd.read_csv(csv_vh[0])

# (for csv_file in csv_vh[1:]:)
for csv_file in csv_vv[1:]:   
    df = pd.read_csv(csv_file)
    df_tot = pd.concat([df, df_tot], ignore_index=True)
    
df_tot
# Out:
#        sigma0  sigma0_filt  incidence  nesz_filt  ground_heading  \
# 0    0.034105          NaN  42.101790        NaN       -9.680160
# 1    0.000037     0.000037  43.060165   0.000902       -9.442317
# 2    0.006182          NaN  43.997420        NaN       -9.214803
# 3    0.037801          NaN  44.922802        NaN       -8.920362
# 4    0.027321          NaN  42.098694        NaN       -9.789651
# ..        ...          ...        ...        ...             ...
# 112  0.012251     0.012251  36.686996   0.002393      -11.113932
# 113  0.009373     0.009373  37.770350   0.001696      -10.859950
# 114  0.007708     0.007708  38.829327   0.001466      -10.605852
# 115  0.006035     0.006034  39.864170   0.001581      -10.351548
# 116  0.004481     0.004481  40.875126   0.002202      -10.097119
#
#      azimuth_cutoff  land_flag      uwnd      vwnd       U10       V10  \
# 0               NaN          1  1.354681  1.500168  0.702067  1.646616
# 1         628.03516          0  1.715722  1.062240  0.355472  2.170305
# 2               NaN          1  1.869679  0.837745  0.681120  1.100452
# 3               NaN          1  1.920611  0.662120  0.982097  0.788485
# 4               NaN          1  1.625638  1.600552  1.241568  1.398968
# ..              ...        ...       ...       ...       ...       ...
# 112       192.63383          0  1.908554  6.107563  1.559376  5.570092
# 113       180.14992          0  1.807137  5.925515  1.420590  5.331285
# 114       172.19308          0  1.645958  5.704806  1.498935  5.301014
# 115       162.08861          0  1.733493  5.370944  1.681418  5.090823
# 116       159.40541          0  1.955129  4.983330  1.785525  4.891180
#
#      normalized_variance_filt  longitude   latitude  macs_Im_lambda_max=50.0  \
# 0                         NaN  -7.250105  57.252403                 0.000000
# 1                    1.159211  -6.967557  57.277695                 0.003124
# 2                         NaN  -6.679415  57.302790                 0.000000
# 3                         NaN  -6.393134  57.327045                 0.000000
# 4                         NaN  -7.303873  57.416553                 0.000000
# ..                        ...        ...        ...                      ...
# 112                  1.134007  -9.191009  58.360756                 0.001550
# 113                  1.143851  -8.897450  58.390080                 0.000285
# 114                  1.140592  -8.603395  58.418728                 0.003614
# 115                  1.126515  -8.308849  58.446705                -0.001765
# 116                  1.107247  -8.013884  58.474003                -0.001189
#
#      macs_Re_lambda_max=50.0  \
# 0                   0.000000
# 1                   0.025811
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# ..                       ...
# 112                 0.025842
# 113                 0.034798
# 114                 0.030870
# 115                 0.020559
# 116                 0.016566
#
#                                              file_path
# 0    /home/datawork-cersat-public/cache/project/sar...
# 1    /home/datawork-cersat-public/cache/project/sar...
# 2    /home/datawork-cersat-public/cache/project/sar...
# 3    /home/datawork-cersat-public/cache/project/sar...
# 4    /home/datawork-cersat-public/cache/project/sar...
# ..                                                 ...
# 112  /home/datawork-cersat-public/cache/project/sar...
# 113  /home/datawork-cersat-public/cache/project/sar...
# 114  /home/datawork-cersat-public/cache/project/sar...
# 115  /home/datawork-cersat-public/cache/project/sar...
# 116  /home/datawork-cersat-public/cache/project/sar...
#
# [117 rows x 17 columns]
