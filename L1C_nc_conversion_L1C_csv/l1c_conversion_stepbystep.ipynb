# %%
import os
import glob
import pandas as pd
import xarray as xr
import numpy as np

# %% [markdown]
# ### Open and read the netcdf file

# %%
path = '/home/datawork-cersat-public/project/sarwave/data/products/tests2/slc/iw/l1c/2017/288/S1B_IW_XSP__1SDV_20171015T184419_20171015T184446_007844_00DD96_2573_B07.SAFE/l1c-s1b-iw3-xsp-1sdv-20171015t184419-20171015t184444-007844-00dd96-b07.nc'

ds = xr.open_dataset(path, group ='intraburst')
ds
# Out:
# <xarray.Dataset> Size: 15MB
# Dimensions:                   (tile_line: 9, tile_sample: 4, pol: 2,
#                                bt_thresh: 5, c_sample: 2, c_line: 2,
#                                freq_sample: 506, freq_line: 50, k_gp: 4,
#                                phi_hf: 5, lambda_range_max_macs: 11, 2tau: 1)
# Coordinates:
#     line                      (tile_line) int16 18B ...
#     sample                    (tile_line, tile_sample) int16 72B ...
#     longitude                 (tile_line, tile_sample) float32 144B ...
#     latitude                  (tile_line, tile_sample) float32 144B ...
#   * pol                       (pol) <U2 16B 'VH' 'VV'
#   * bt_thresh                 (bt_thresh) int16 10B 5 50 100 150 200
#     k_rg                      (tile_line, tile_sample, freq_sample) float32 73kB ...
#     k_az                      (freq_line) float32 200B ...
#   * k_gp                      (k_gp) int16 8B 1 2 3 4
#   * phi_hf                    (phi_hf) int16 10B 1 2 3 4 5
#   * lambda_range_max_macs     (lambda_range_max_macs) float32 44B 25.0 ... 275.0
#     crs                       int16 2B ...
# Dimensions without coordinates: tile_line, tile_sample, c_sample, c_line,
#                                 freq_sample, freq_line, 2tau
# Data variables: (12/116)
#     incidence                 (tile_line, tile_sample) float32 144B ...
#     ground_heading            (tile_line, tile_sample) float32 144B ...
#     sensing_time              (tile_line, tile_sample) datetime64[ns] 288B ...
#     tile_width_sample         (tile_line, tile_sample) int16 72B ...
#     tile_width_line           (tile_line, tile_sample) int16 72B ...
#     sigma0                    (tile_line, tile_sample, pol) float32 288B ...
#     ...                        ...
#     vabr                      (tile_line, tile_sample) float32 144B ...
#     uubr                      (tile_line, tile_sample) float32 144B ...
#     vubr                      (tile_line, tile_sample) float32 144B ...
#     mssu                      (tile_line, tile_sample) float32 144B ...
#     mssc                      (tile_line, tile_sample) float32 144B ...
#     mssd                      (tile_line, tile_sample) float32 144B ...
# Attributes: (12/24)
#     orbit_pass:                    Ascending
#     azimuth_time_interval:         0.002055556299999998
#     short_name:                    SENTINEL1_DS:S1B_IW_SLC__1SDV_20171015T184...
#     required_tile_width_line:      17500
#     product:                       SLC
#     swath:                         IW
#     ...                            ...
#     platform:                      SENTINEL-1B
#     required_tile_width_sample:    17500
#     history:                       digital_number: measurement/s1b-iw3-slc-v*...
#     name:                          SENTINEL1_DS:/home/datawork-cersat-public/...
#     azimuth_steering_rate:         1.397440818
#     ipf:                           2.84

# %%
selected_vars = ['sigma0_filt','incidence','nesz', 'ground_heading','land_flag',
                 'uwnd', 'vwnd','U10', 'V10', 'macs_Im', 'macs_Re', 'normalized_variance_filt']


if not set(selected_vars).issubset(ds.keys()):
            print(f'All Variables not found in {path}')
            #return None

ds = ds.drop_vars('crs')
ds = ds[selected_vars]
display(ds)
# Out:
# All Variables not found in /home/datawork-cersat-public/project/sarwave/data/products/tests2/slc/iw/l1c/2017/263/S1B_IW_XSP__1SDV_20170920T102318_20170920T102345_007474_00D31F_10FD_B07.SAFE/l1c-s1b-iw3-xsp-1sdv-20170920t102318-20170920t102343-007474-00d31f-b07.nc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home1/datawork/ljessel/micromamba-env/xsar_env_py3.9/lib/python3.9/site-packages/xarray/core/dataset.py in ?(self, names)
#    1408                 variables[name] = self._variables[name]
#    1409             except KeyError:
# -> 1410                 ref_name, var_name, var = _get_virtual_variable(
#    1411                     self._variables, name, self.sizes
#
# KeyError: 'U10'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /dev/shm/pbs.434699.datarmor0/ipykernel_26690/2228018538.py in ?()
# ---> 10 selected_vars = ['sigma0_filt','incidence','nesz', 'ground_heading','land_flag',
#      11                  'uwnd', 'vwnd','U10', 'V10', 'macs_Im', 'macs_Re', 'normalized_variance_filt']
#      12
#      13
#
# /home1/datawork/ljessel/micromamba-env/xsar_env_py3.9/lib/python3.9/site-packages/xarray/core/dataset.py in ?(self, key)
#    1548                     f"No variable named {key!r}. Variables on the dataset include {shorten_list_repr(list(self.variables.keys()), max_items=10)}"
#    1549                 ) from e
#    1550
#    1551         if utils.iterable_of_hashable(key):
# -> 1552             return self._copy_listed(key)
#    1553         raise ValueError(f"Unsupported key-type {type(key)}")
#
# /home1/datawork/ljessel/micromamba-env/xsar_env_py3.9/lib/python3.9/site-packages/xarray/core/dataset.py in ?(self, names)
#    1406         for name in names:
#    1407             try:
#    1408                 variables[name] = self._variables[name]
#    1409             except KeyError:
# -> 1410                 ref_name, var_name, var = _get_virtual_variable(
#    1411                     self._variables, name, self.sizes
#    1412                 )
#    1413                 variables[var_name] = var
#
# /home1/datawork/ljessel/micromamba-env/xsar_env_py3.9/lib/python3.9/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     203         raise KeyError(key)
#     204
#     205     split_key = key.split(".", 1)
#     206     if len(split_key) != 2:
# --> 207         raise KeyError(key)
#     208
#     209     ref_name, var_name = split_key
#     210     ref_var = variables[ref_name]
#
# KeyError: 'U10'

# %%
# Supposons que 'pol', 'tile_line', et 'tile_sample' soient les dimensions pertinentes
tile_line = ds.sizes['tile_line']; tile_sample = ds.sizes['tile_sample']
pol_values = ds['pol'].values  # ['VH', 'VV']

display(tile_line, tile_sample, pol_values)
# Créer une grille pour les dimensions
tile_line_indices, tile_sample_indices, pol_indices = np.meshgrid(np.arange(tile_line), np.arange(tile_sample), np.arange(len(pol_values)), indexing='ij')

# Réorganiser les indices pour qu'ils soient sous forme linéaire
pol_indices = pol_indices.ravel()

# Obtenir les valeurs de 'pol' associées aux indices
expanded_pol = pol_values[pol_indices]

# Convertir le dataset en DataFrame
df_res = ds.drop_dims(['lambda_range_max_macs']).squeeze().to_dataframe().reset_index(drop=True).drop(columns=['spatial_ref', 'sample', 'line'], errors='ignore')

# Ajouter la colonne 'pola' avec les valeurs correctement alignées
df_res['pola'] = expanded_pol
df_res
# Out:
# 9
# 5
# array(['VH', 'VV'], dtype='<U2')
#     sigma0_filt  incidence      nesz  ground_heading  land_flag      uwnd  \
# 0           NaN  36.645969  0.002884      -11.656672       True -3.123083
# 1           NaN  36.645969  0.002547      -11.656672       True -3.123083
# 2      0.000150  37.728565  0.002138      -11.337094      False -2.708674
# 3      0.014344  37.728565  0.001876      -11.337094      False -2.708674
# 4      0.000132  38.787601  0.001923      -11.057025      False -2.619153
# ..          ...        ...       ...             ...        ...       ...
# 85     0.050575  38.775448  0.001664      -11.282922      False -8.300492
# 86     0.001234  39.810261  0.002005      -10.975616      False -8.340130
# 87     0.047706  39.810261  0.001723      -10.975616      False -8.340130
# 88     0.001088  40.821430  0.002622      -10.667827      False -8.327045
# 89     0.041967  40.821430  0.002271      -10.667827      False -8.327045
#
#         vwnd       U10       V10  normalized_variance_filt  longitude  \
# 0   7.790683 -2.632508  7.035500                       NaN  -6.448264
# 1   7.790683 -2.632508  7.035500                       NaN  -6.448264
# 2   7.691035 -2.268131  7.284603                  1.191188  -6.122775
# 3   7.691035 -2.268131  7.284603                  1.188372  -6.122775
# 4   7.559871 -2.190142  7.034854                  1.086010  -5.796837
# ..       ...       ...       ...                       ...        ...
# 85  8.016449 -9.440802  9.261126                  1.231618  -6.344853
# 86  7.723401 -8.938865  8.594180                  1.099593  -6.003569
# 87  7.723401 -8.938865  8.594180                  1.215896  -6.003569
# 88  7.528501 -8.020763  7.828473                  1.081216  -5.661509
# 89  7.528501 -8.020763  7.828473                  1.198841  -5.661509
#
#      latitude pola
# 0   61.827137   VH
# 1   61.827137   VV
# 2   61.857773   VH
# 3   61.857773   VV
# 4   61.887619   VH
# ..        ...  ...
# 85  63.194866   VV
# 86  63.224537   VH
# 87  63.224537   VV
# 88  63.253391   VH
# 89  63.253391   VV
#
# [90 rows x 13 columns]

# %%
for _lambda_max in ds['lambda_range_max_macs'].values:
    df = ds[['macs_Im', 'macs_Re']].sel(lambda_range_max_macs = _lambda_max).to_dataframe().reset_index(drop=True).drop(columns=['lambda_range_max_macs', 'spatial_ref', 'sample', 'line', 'pol'], errors='ignore')
    df = df.rename(columns={'macs_Im': f'macs_Im_lambda_max={_lambda_max}',
                            'macs_Re': f'macs_Re_lambda_max={_lambda_max}'})
    df['pola']=expanded_pol
    df_res = df_res.merge(df, on=['longitude', 'latitude','pola'])

#df_res2 = pd.merge(df, df_res1, on=['longitude', 'latitude','pola'], how='inner')
display(df_res)
# Out:
#     sigma0_filt  incidence      nesz  ground_heading  land_flag      uwnd  \
# 0           NaN  36.645969  0.002884      -11.656672       True -3.123083
# 1           NaN  36.645969  0.002547      -11.656672       True -3.123083
# 2      0.000150  37.728565  0.002138      -11.337094      False -2.708674
# 3      0.014344  37.728565  0.001876      -11.337094      False -2.708674
# 4      0.000132  38.787601  0.001923      -11.057025      False -2.619153
# ..          ...        ...       ...             ...        ...       ...
# 85     0.050575  38.775448  0.001664      -11.282922      False -8.300492
# 86     0.001234  39.810261  0.002005      -10.975616      False -8.340130
# 87     0.047706  39.810261  0.001723      -10.975616      False -8.340130
# 88     0.001088  40.821430  0.002622      -10.667827      False -8.327045
# 89     0.041967  40.821430  0.002271      -10.667827      False -8.327045
#
#         vwnd       U10       V10  normalized_variance_filt  ...  \
# 0   7.790683 -2.632508  7.035500                       NaN  ...
# 1   7.790683 -2.632508  7.035500                       NaN  ...
# 2   7.691035 -2.268131  7.284603                  1.191188  ...
# 3   7.691035 -2.268131  7.284603                  1.188372  ...
# 4   7.559871 -2.190142  7.034854                  1.086010  ...
# ..       ...       ...       ...                       ...  ...
# 85  8.016449 -9.440802  9.261126                  1.231618  ...
# 86  7.723401 -8.938865  8.594180                  1.099593  ...
# 87  7.723401 -8.938865  8.594180                  1.215896  ...
# 88  7.528501 -8.020763  7.828473                  1.081216  ...
# 89  7.528501 -8.020763  7.828473                  1.198841  ...
#
#     macs_Im_lambda_max=175.0  macs_Re_lambda_max=175.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                  -0.003768                  0.021012
# 3                  -0.006627                  0.110317
# 4                   0.001091                  0.018090
# ..                       ...                       ...
# 85                 -0.003486                  0.090631
# 86                  0.002545                  0.028001
# 87                  0.003278                  0.092518
# 88                 -0.001866                  0.025538
# 89                 -0.006785                  0.092593
#
#    macs_Im_lambda_max=200.0  macs_Re_lambda_max=200.0  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                 -0.003654                  0.021043
# 3                 -0.007127                  0.111995
# 4                  0.001094                  0.018020
# ..                      ...                       ...
# 85                -0.003051                  0.109357
# 86                 0.002044                  0.030065
# 87                 0.003620                  0.108518
# 88                -0.001749                  0.026740
# 89                -0.005872                  0.103569
#
#     macs_Im_lambda_max=225.0  macs_Re_lambda_max=225.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                  -0.003693                  0.021435
# 3                  -0.007607                  0.114068
# 4                   0.000964                  0.018174
# ..                       ...                       ...
# 85                 -0.002420                  0.129765
# 86                  0.001852                  0.032554
# 87                  0.004722                  0.124121
# 88                 -0.001453                  0.027524
# 89                 -0.005850                  0.118683
#
#     macs_Im_lambda_max=250.0  macs_Re_lambda_max=250.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                  -0.003868                  0.021835
# 3                  -0.007875                  0.115976
# 4                   0.000968                  0.018386
# ..                       ...                       ...
# 85                 -0.002756                  0.140739
# 86                  0.001724                  0.033653
# 87                  0.005291                  0.133901
# 88                 -0.001330                  0.029135
# 89                 -0.003956                  0.140597
#
#     macs_Im_lambda_max=275.0  macs_Re_lambda_max=275.0
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                  -0.003611                  0.022270
# 3                  -0.007781                  0.117461
# 4                   0.001015                  0.018271
# ..                       ...                       ...
# 85                 -0.003269                  0.177529
# 86                  0.002306                  0.038656
# 87                  0.004065                  0.167291
# 88                 -0.001464                  0.030713
# 89                 -0.004398                  0.156607
#
# [90 rows x 35 columns]

# %%
df_res = df_res.assign(file_path=path)
df_res
# Out:
#     sigma0_filt  incidence      nesz  ground_heading  land_flag      uwnd  \
# 0           NaN  36.645969  0.002884      -11.656672       True -3.123083
# 1           NaN  36.645969  0.002547      -11.656672       True -3.123083
# 2      0.000150  37.728565  0.002138      -11.337094      False -2.708674
# 3      0.014344  37.728565  0.001876      -11.337094      False -2.708674
# 4      0.000132  38.787601  0.001923      -11.057025      False -2.619153
# ..          ...        ...       ...             ...        ...       ...
# 85     0.050575  38.775448  0.001664      -11.282922      False -8.300492
# 86     0.001234  39.810261  0.002005      -10.975616      False -8.340130
# 87     0.047706  39.810261  0.001723      -10.975616      False -8.340130
# 88     0.001088  40.821430  0.002622      -10.667827      False -8.327045
# 89     0.041967  40.821430  0.002271      -10.667827      False -8.327045
#
#         vwnd       U10       V10  normalized_variance_filt  ...  \
# 0   7.790683 -2.632508  7.035500                       NaN  ...
# 1   7.790683 -2.632508  7.035500                       NaN  ...
# 2   7.691035 -2.268131  7.284603                  1.191188  ...
# 3   7.691035 -2.268131  7.284603                  1.188372  ...
# 4   7.559871 -2.190142  7.034854                  1.086010  ...
# ..       ...       ...       ...                       ...  ...
# 85  8.016449 -9.440802  9.261126                  1.231618  ...
# 86  7.723401 -8.938865  8.594180                  1.099593  ...
# 87  7.723401 -8.938865  8.594180                  1.215896  ...
# 88  7.528501 -8.020763  7.828473                  1.081216  ...
# 89  7.528501 -8.020763  7.828473                  1.198841  ...
#
#     macs_Re_lambda_max=175.0  macs_Im_lambda_max=200.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   0.021012                 -0.003654
# 3                   0.110317                 -0.007127
# 4                   0.018090                  0.001094
# ..                       ...                       ...
# 85                  0.090631                 -0.003051
# 86                  0.028001                  0.002044
# 87                  0.092518                  0.003620
# 88                  0.025538                 -0.001749
# 89                  0.092593                 -0.005872
#
#    macs_Re_lambda_max=200.0  macs_Im_lambda_max=225.0  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                  0.021043                 -0.003693
# 3                  0.111995                 -0.007607
# 4                  0.018020                  0.000964
# ..                      ...                       ...
# 85                 0.109357                 -0.002420
# 86                 0.030065                  0.001852
# 87                 0.108518                  0.004722
# 88                 0.026740                 -0.001453
# 89                 0.103569                 -0.005850
#
#     macs_Re_lambda_max=225.0  macs_Im_lambda_max=250.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   0.021435                 -0.003868
# 3                   0.114068                 -0.007875
# 4                   0.018174                  0.000968
# ..                       ...                       ...
# 85                  0.129765                 -0.002756
# 86                  0.032554                  0.001724
# 87                  0.124121                  0.005291
# 88                  0.027524                 -0.001330
# 89                  0.118683                 -0.003956
#
#     macs_Re_lambda_max=250.0  macs_Im_lambda_max=275.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   0.021835                 -0.003611
# 3                   0.115976                 -0.007781
# 4                   0.018386                  0.001015
# ..                       ...                       ...
# 85                  0.140739                 -0.003269
# 86                  0.033653                  0.002306
# 87                  0.133901                  0.004065
# 88                  0.029135                 -0.001464
# 89                  0.140597                 -0.004398
#
#     macs_Re_lambda_max=275.0  \
# 0                        NaN
# 1                        NaN
# 2                   0.022270
# 3                   0.117461
# 4                   0.018271
# ..                       ...
# 85                  0.177529
# 86                  0.038656
# 87                  0.167291
# 88                  0.030713
# 89                  0.156607
#
#                                             file_path
# 0   /home/datawork-cersat-public/project/sarwave/d...
# 1   /home/datawork-cersat-public/project/sarwave/d...
# 2   /home/datawork-cersat-public/project/sarwave/d...
# 3   /home/datawork-cersat-public/project/sarwave/d...
# 4   /home/datawork-cersat-public/project/sarwave/d...
# ..                                                ...
# 85  /home/datawork-cersat-public/project/sarwave/d...
# 86  /home/datawork-cersat-public/project/sarwave/d...
# 87  /home/datawork-cersat-public/project/sarwave/d...
# 88  /home/datawork-cersat-public/project/sarwave/d...
# 89  /home/datawork-cersat-public/project/sarwave/d...
#
# [90 rows x 36 columns]

# %%
root_savepath = '/home1/datahome/ljessel/l1c_conversion/'
burst_type = 'intraburst'

safe_name, file_name = path.split(os.sep)[-2:]
savepath = os.path.join(root_savepath, safe_name, burst_type, file_name).replace('.nc', '.csv')

os.makedirs(os.path.dirname(savepath), exist_ok=True)
df_res.to_csv(savepath, index=False)

# %%
csv_path = '/home1/datahome/ljessel/l1c_conversion/S1A_IW_XSP__1SDV_20210115T180059_20210115T180125_036152_043D21_9982_B07.SAFE/intraburst/l1c-s1a-iw2-xsp-1sdv-20210115t180059-20210115t180124-036152-043d21-b07.csv' 

pd.read_csv(csv_path)
# Out:
#     sigma0_filt  incidence      nesz  ground_heading  land_flag      uwnd  \
# 0           NaN  36.645970  0.002884      -11.656672       True -3.123083
# 1           NaN  36.645970  0.002547      -11.656672       True -3.123083
# 2      0.000150  37.728565  0.002138      -11.337094      False -2.708674
# 3      0.014344  37.728565  0.001876      -11.337094      False -2.708674
# 4      0.000132  38.787600  0.001923      -11.057025      False -2.619153
# ..          ...        ...       ...             ...        ...       ...
# 85     0.050575  38.775448  0.001664      -11.282922      False -8.300492
# 86     0.001234  39.810260  0.002005      -10.975616      False -8.340130
# 87     0.047706  39.810260  0.001723      -10.975616      False -8.340130
# 88     0.001088  40.821430  0.002622      -10.667827      False -8.327045
# 89     0.041967  40.821430  0.002271      -10.667827      False -8.327045
#
#         vwnd       U10       V10  normalized_variance_filt  ...  \
# 0   7.790683 -2.632508  7.035500                       NaN  ...
# 1   7.790683 -2.632508  7.035500                       NaN  ...
# 2   7.691035 -2.268130  7.284603                  1.191188  ...
# 3   7.691035 -2.268130  7.284603                  1.188372  ...
# 4   7.559871 -2.190142  7.034854                  1.086010  ...
# ..       ...       ...       ...                       ...  ...
# 85  8.016449 -9.440802  9.261126                  1.231618  ...
# 86  7.723401 -8.938865  8.594180                  1.099593  ...
# 87  7.723401 -8.938865  8.594180                  1.215896  ...
# 88  7.528501 -8.020763  7.828473                  1.081216  ...
# 89  7.528501 -8.020763  7.828473                  1.198841  ...
#
#     macs_Re_lambda_max=175.0  macs_Im_lambda_max=200.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   0.021012                 -0.003654
# 3                   0.110317                 -0.007127
# 4                   0.018090                  0.001094
# ..                       ...                       ...
# 85                  0.090631                 -0.003051
# 86                  0.028001                  0.002044
# 87                  0.092518                  0.003620
# 88                  0.025538                 -0.001749
# 89                  0.092593                 -0.005872
#
#    macs_Re_lambda_max=200.0  macs_Im_lambda_max=225.0  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                  0.021043                 -0.003693
# 3                  0.111995                 -0.007607
# 4                  0.018020                  0.000964
# ..                      ...                       ...
# 85                 0.109357                 -0.002420
# 86                 0.030065                  0.001852
# 87                 0.108518                  0.004722
# 88                 0.026740                 -0.001453
# 89                 0.103569                 -0.005850
#
#     macs_Re_lambda_max=225.0  macs_Im_lambda_max=250.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   0.021435                 -0.003868
# 3                   0.114068                 -0.007875
# 4                   0.018174                  0.000968
# ..                       ...                       ...
# 85                  0.129765                 -0.002756
# 86                  0.032554                  0.001724
# 87                  0.124121                  0.005291
# 88                  0.027524                 -0.001330
# 89                  0.118683                 -0.003956
#
#     macs_Re_lambda_max=250.0  macs_Im_lambda_max=275.0  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   0.021835                 -0.003611
# 3                   0.115976                 -0.007781
# 4                   0.018386                  0.001015
# ..                       ...                       ...
# 85                  0.140739                 -0.003269
# 86                  0.033653                  0.002306
# 87                  0.133901                  0.004065
# 88                  0.029135                 -0.001464
# 89                  0.140597                 -0.004398
#
#     macs_Re_lambda_max=275.0  \
# 0                        NaN
# 1                        NaN
# 2                   0.022270
# 3                   0.117461
# 4                   0.018271
# ..                       ...
# 85                  0.177529
# 86                  0.038656
# 87                  0.167291
# 88                  0.030713
# 89                  0.156607
#
#                                             file_path
# 0   /home/datawork-cersat-public/project/sarwave/d...
# 1   /home/datawork-cersat-public/project/sarwave/d...
# 2   /home/datawork-cersat-public/project/sarwave/d...
# 3   /home/datawork-cersat-public/project/sarwave/d...
# 4   /home/datawork-cersat-public/project/sarwave/d...
# ..                                                ...
# 85  /home/datawork-cersat-public/project/sarwave/d...
# 86  /home/datawork-cersat-public/project/sarwave/d...
# 87  /home/datawork-cersat-public/project/sarwave/d...
# 88  /home/datawork-cersat-public/project/sarwave/d...
# 89  /home/datawork-cersat-public/project/sarwave/d...
#
# [90 rows x 36 columns]
